# %%
#Importamos las librerias necesarias

import pandas as p
import numpy as np
import sqlite3 #sqlite datasets
import matplotlib.pyplot as plt

# %%
# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("../laliga.sqlite")
df = pd.read_sql_query("SELECT * from Matches", con)
df # prueba de que me lo lee

# RECUERDA cuando termines de usar el archivo hacer con.close()
# Out:
#           season  division  matchday     date  time        home_team  \
# 0      1928-1929         1         1  2/10/29  None      Arenas Club
# 1      1928-1929         1         1  2/10/29  None         Espanyol
# 2      1928-1929         1         1  2/10/29  None      Real Madrid
# 3      1928-1929         1         1  2/10/29  None         Donostia
# 4      1928-1929         1         1  2/12/29  None           Racing
# ...          ...       ...       ...      ...   ...              ...
# 48775  2021-2022         2        42  5/29/22  None      Real Oviedo
# 48776  2021-2022         2        42  5/29/22  None  Real Sociedad B
# 48777  2021-2022         2        42  5/29/22  None   Sporting Gijón
# 48778  2021-2022         2        42  5/29/22  None      CD Tenerife
# 48779  2021-2022         2        42  5/29/22  None  Real Valladolid
#
#              away_team score
# 0      Athletic Madrid   2:3
# 1           Real Unión   3:2
# 2            Catalunya   5:0
# ...

# %% [markdown]
# 1. Is it true that the home team is more likely to win? Make a pie chart showing the result distribution (whether home team wins, visitor team wins, or
# there’s a tie) of all matches in the data. Write in the plot the percentage of each category.

# %%
# Añadimos una nueva columna al df winner
df['goals_home'] = df["score"].str.split(":").str[0]
df['goals_visitor'] = df["score"].str.split(":").str[1]
df['winner'] = np.where(df["score"].str.split(":").str[0]>df["score"].str.split(":").str[1], "Home", 
                        np.where(df["score"].str.split(":").str[0]<df["score"].str.split(":").str[1], "Away", "Tie"))
df
# Out:
#           season  division  matchday     date  time        home_team  \
# 0      1928-1929         1         1  2/10/29  None      Arenas Club
# 1      1928-1929         1         1  2/10/29  None         Espanyol
# 2      1928-1929         1         1  2/10/29  None      Real Madrid
# 3      1928-1929         1         1  2/10/29  None         Donostia
# 4      1928-1929         1         1  2/12/29  None           Racing
# ...          ...       ...       ...      ...   ...              ...
# 48775  2021-2022         2        42  5/29/22  None      Real Oviedo
# 48776  2021-2022         2        42  5/29/22  None  Real Sociedad B
# 48777  2021-2022         2        42  5/29/22  None   Sporting Gijón
# 48778  2021-2022         2        42  5/29/22  None      CD Tenerife
# 48779  2021-2022         2        42  5/29/22  None  Real Valladolid
#
#              away_team score winner goals_home goals_visitor
# 0      Athletic Madrid   2:3   Away          2             3
# ...

# %%
winner_team = df["winner"].value_counts()
winner_team.plot(kind="pie", ylabel = "Winner", autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Winner'>

# %% [markdown]
# 2. What are the top ten scoring teams of all time? What are the ten teams that concede the most? Make two bar plot charts showing each of them. Consider only matches played in 1st division. What have been the biggest wins? Of course, when we say biggest we mean those with the highest goal difference. Show the top ten of them in a table.

# %%
df1=pd.DataFrame(df.groupby("home_team")["goals_home"].sum())
df2=pd.DataFrame(df.groupby("away_team")["goals_visitor"].sum())
new_df = pd.concat([df1, df2], axis=1)
new_df["total_goals"] = sum(new_df["goals_home"], new_df["goals_visitor"])
new_df=new_df.drop(["goals_home", "goals_visitor"], axis=1)
new_df.sort_values("total_goals", ascending=False, inplace=True)
dftop10 = new_df.head(10)
dftop10
# Out:
#                                                        total_goals
# Levante          4304000010220200001212012001101033100011202112...
# Atl. Aviación    3420201210111011302122102012243022105221103012...
# Ath. Aviación    3311002202015131324413110032431122223111101130...
# Real Oviedo      3201102210321341125216241220505021101100000112...
# Athletic Madrid  3121230230221012010010220001210031121111104112...
# UD Almería       3111001111001134022302011102221100020002021120...
# Donostia         3103321010221011211453021101210000012201202200...
# Recr. Huelva     3100000001100032001010020101311000001310232310...
# CD Alcoyano      3012102011001201203200021311002111130012301011...
# Lorca Dep.       3012000032331010023100110201011110110100101100...

# %% [markdown]
# Esto es una prueba.

# %% [markdown]
# Esto es otra prueba.
